# %%
import os
import glob
import psycopg2
import pandas as pd
import numpy as np
from Create_Table_queries import *
import warnings
warnings.filterwarnings('ignore')

# %load_ext autoreload
# %autoreload 2

def process_youtubedata_file(cur, conn, filepath): 
    """
        This function reads one JSON file and read information of videos and youtuber data and saves into video_data and youtuber_data
        Arguments:
        cur: Database Cursor
        filepath: location of JSON files
        Return: None
    """
    # open JSON file
    df = pd.read_json(filepath)
    df.fillna('')
    
    # ---------insert youtuber record----------
    # write your code here that reads youtuber data from JSON file and insert it into Youtubers_dim table 
    # write your code here
    
    youtuber_data = df[['youtuber_id', 'youtuber_name', 'youtuber_location', 'youtuber_latitude', 'youtuber_longitude']]
    youtuber_data = youtuber_data.drop_duplicates()
    youtuber_data = youtuber_data.values.tolist()

    try: 
        cur.executemany(Youtubers_table_insert, youtuber_data)
    except psycopg2.Error as e:
        print(e)
    

    
    # ---------insert video record--------------
    # write your code here that reads youtube videos data from JSON file and insert it into Videos_dim table 
    # write your code here
    
    video_data = df[['video_id', 'title', 'youtuber_id', 'year', 'duration']]
    video_data = video_data.drop_duplicates(keep='first')
    video_data = video_data.values.tolist()
    
    try: 
        cur.executemany(Videos_table_insert, video_data)
    except psycopg2.Error as e:
        print(e)

def process_log_file(cur, conn, filepath):
    """
        This function reads Log files and reads information of time, user and videoplay data and saves into time, user, videoplay
        Arguments:
        cur: Database Cursor
        filepath: location of Log files
        Return: None
    """

    # open log file
    df = pd.read_json(filepath, lines=True)

    # filter by NextVideo action
    df = df[(df['page'] == 'NextVideo')]

    # convert timestamp column to datetime with 'pd.to_datetime(df["ts"], unit="ms")' 
    df['ts'] = pd.to_datetime(df["ts"], unit="ms")
    
    # insert time data records to Time_dim table
    # write your code here
    df['year'] =  pd.to_datetime(df['ts']).dt.year
    df['month'] =  pd.to_datetime(df['ts']).dt.month
    df['day'] =  pd.to_datetime(df['ts']).dt.day
    df['hour'] =  pd.to_datetime(df['ts']).dt.hour
    df['week'] =  pd.to_datetime(df['ts']).dt.week
    df['weekday'] =  pd.to_datetime(df['ts']).dt.weekday
    df['start_time'] =  pd.to_datetime(df['ts'])
    
    time_data = df[['start_time', 'hour', 'day', 'week', 'month', 'year', 'weekday']]
    time_data = time_data.drop_duplicates(keep='first')
    time_data = time_data.values
    try: 
        cur.executemany(Time_table_insert, time_data)
    except psycopg2.Error as e:
        print(e)

    
    # load user table
    # insert user records into Users_dim table
    # write your code here
    user_data = df[['userId', 'firstName', 'lastName', 'gender', 'level']]
    user_data = user_data.drop_duplicates(keep='first')
    user_data = user_data.values
    try: 
        cur.executemany(Users_table_insert, user_data)
    except psycopg2.Error as e:
        print(e)

    
    # insert Videoplay records in Videoplay_fact table
    # write your code here
    
    # reading videos data
    query = 'SELECT * from videos_dim;'
    videos = pd.read_sql_query(query,conn)
    
    # merging tables to get information of video_id and youtuber_id
    df1 = pd.merge(df, videos, how='inner', left_on = 'video', right_on = 'title')
    
    videoplay_data = df1[['start_time', 'userId', 'level','video_id', 'youtuber_id', 'sessionId','location','userAgent']]
    videoplay_data = videoplay_data.drop_duplicates(keep='first')
    videoplay_data = videoplay_data.values
    try: 
        cur.executemany(Videoplay_table_insert, videoplay_data)
    except psycopg2.Error as e:
        print(e)
    
def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
                
    return allFiles 

def process_data(cur, conn, filepath, func):
    """
        This function get all JSON files in given directory by exploring all sub directories, and process all files that were found using the given function.
        Example: if I give it the path to youtube_data directory which resides in data folder of this assignment,
        and func given is process_youtubedata_file it should get all JSON files in this directories and process each file using process_youtubedata_file function. 
        Arguments:
        cur: Database Cursor
        conn: Database
        filepath: location of JSON files
        func: function to process all files in the directory
        Return: None
    """
    file_list = getListOfFiles(filepath)
    for file in file_list:
        func(cur,conn,file)



def main():
    conn = psycopg2.connect("host=127.0.0.1 dbname=youtubedb user=postgres password=ali123ali")
    cur = conn.cursor()
    conn.set_session(autocommit=True)

    process_data(cur, conn, filepath='data/youtube_data', func=process_youtubedata_file)
    process_data(cur, conn, filepath='data/log_data', func=process_log_file)

    conn.close()


if __name__ == "__main__":
    main()
# Out:
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARD7TVE1187B99BFB1) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOMZWCG12A8C13C480) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARMJAGH1187FB546F3) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOCIWDW12A8C13D406) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARKRRTF1187B9984DA) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOXVLOJ12AB0189215) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AR7G5I41187FB4CE6C) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SONHOTT12A8C13493C) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARXR32B1187FB57099) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOFSOCN12A8C143F5D) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARKFYS91187B98E58F) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOYMRWW12A6D4FAB14) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARD0S291187B9B7BF5) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOMJBYD12A6D4F8557) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AR10USD1187B99F3F1) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOHKNRJ12A6701D1F8) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AR8ZCNI1187B9A069B) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOIAZJW12AB01853F1) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARNTLGG11E2835DDB9) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOUDSGM12AC9618304) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARGSJW91187B9B1D6B) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOQHXMF12AB0182363) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARC43071187B990240) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOKEJEJ12A8C13E0D0) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARL7K851187B99ACD2) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOMUYGI12AB0188633) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARHHO3O1187B989413) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SORAMLE12AB017C8B0) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARIK43K1187B9AE54C) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOBONFF12A6D4F84D8) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARD842G1187B997376) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOHUOAP12A8AE488E9) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARIG6O41187B988BDD) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOUQQEA12A8C134B1B) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AR1ZHYZ1187FB3C717) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOILPQQ12AB017E82A) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARYKCQI1187FB3B18F) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOXLBJT12A8C140925) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARNPAGP1241B9C7FD4) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOZVMJI12AB01808AF) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARQGYP71187FB44566) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOWTBJW12AC468AC6E) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARI3BMM1187FB4255E) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOBEBDG12A58A76D60) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AR5KOSW1187FB35FF4) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOZCTXZ12AB0182364) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARMAC4T1187FB3FA4C) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOBBUGU12A8C13E95D) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AR47JEX1187B995D81) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOBLGCN12AB0183212) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARGIWFO1187B9B55B7) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOPSWQW12A6D4F8781) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARNTLGG11E2835DDB9) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOZQDIU12A58A7BCF6) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARDNS031187B9924F0) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SONYPOM12A8C13B2D7) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AROUOZZ1187B9ABE51) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOBZBAZ12A6D4F8742) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARH4Z031187B9A71F2) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOVYKGO12AB0187199) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARB29H41187B98F0EF) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOGNCJP12A58A80271) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AR1Y2PT1187FB5B9CE) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOLLHMX12AB01846DC) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARAJPHH1187FB5566A) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOYTPEP12AB0180E7B) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AR0RCMP1187FB3F427) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOGXHEG12AB018653E) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AREBBGV1187FB523D2) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOOLYAZ12A6701F4A6) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARGUVEV1187B98BA17) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOGOSOV12AF72A285E) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARD7TVE1187B99BFB1) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOQLGFP12A58A7800E) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AR3JMC51187B9AE49D) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOPVXLX12A8C1402D5) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARPBNLO1187FB3D52F) already exists.
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOAOIBZ12AB01815BE) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AR9AWNF1187B9AB0B4) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOZHPGD12A8C1394FE) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AROGWRA122988FEE45) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOSLAVG12A8C13397F) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARMBR4Y1187B9990EB) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOTTDKS12AB018D69B) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARQ9BO41187FB5CF1F) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOMVWWT12A58A7AE05) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARKULSX1187FB45F84) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOQVMXR12A81C21483) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARI2JSK1187FB496EF) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SODUJBS12A8C132150) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AREDBBQ1187B98AFF5) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOBBXLX12A58A79DDA) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AR7ZKHQ1187B98DD73) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOTUKVB12AB0181477) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARBGXIG122988F409D) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOOJPRH12A8C141995) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AR7SMBG1187B9B9066) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOBCOSW12A8C13D398) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARGCY1Y1187B9A4FA5) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOQOTLQ12AB01868D0) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AR36F9J1187FB406F1) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOBKWDJ12A8C13B2F3) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARNNKDK1187B98BBD5) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOFNOQK12AB01840FC) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AR62SOJ1187FB47BB5) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOGVQGJ12AB017F169) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARBEBBY1187B9B43DB) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOFFKZS12AB017F194) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARDR4AC1187FB371A1) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOBAYLL12A8C138AF9) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARAGB2O1187FB3A161) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOLEYHO12AB0188A85) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AREDL271187FB40F44) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOPEGZN12AB0181B3D) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARP6N5A1187B99D1A3) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOXILUQ12A58A7C72A) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARGSAFR1269FB35070) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOTCKKY12AB018A141) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARULZCI1241B9C8611) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOSWKAV12AB018FC91) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AR0IAWL1187B9A96D0) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SONSKXP12A8C13A2C9) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARJIE2Y1187B994AB7) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOUPIRU12A6D4FA1E1) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARLTWXK1187FB5A3F8) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SODREIN12A58A7F2E5) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARNF6401187FB57032) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SONWXQJ12A8C134D94) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARPFHN61187FB575F6) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOWQTQZ12A58A7B63E) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AR051KA1187B98B2FF) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOLYIBD12A8C135045) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AR8IEZO1187B99055E) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOINLJW12A8C13314C) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AR558FS1187FB45658) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOGDBUF12A8C140FAA) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARVBRGZ1187FB4675A) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SORRZGD12A6310DBC3) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(ARWB3G61187FB49404) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SODAUVL12A8C13D184) already exists.
#
# duplicate key value violates unique constraint "youtubers_dim_pkey"
# DETAIL:  Key (youtuber_id)=(AREVWGE1187B9B890A) already exists.
#
# duplicate key value violates unique constraint "videos_dim_pkey"
# DETAIL:  Key (video_id)=(SOFCHDR12AB01866EF) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-01 21:01:46.796) already exists.
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(8) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-02 01:25:34.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(101) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-03 01:05:50.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(53) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-04 00:50:03.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(99) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-05 00:33:12.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(69) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-06 02:13:03.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(100) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-07 00:01:16.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(97) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-08 01:11:50.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(20) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-09 00:06:17.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(42) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-10 00:15:27.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(96) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-11 02:33:56.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(69) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-12 02:37:38.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(10) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-13 00:40:37.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(66) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-14 00:03:22.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(95) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-15 00:30:26.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(26) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-16 00:00:57.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(44) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-17 00:02:24.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(49) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-18 02:33:21.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(83) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-19 01:54:56.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(7) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-20 00:00:42.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(25) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-21 00:57:58.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(80) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-22 00:03:52.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(15) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-23 00:07:25.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(66) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-24 00:45:00.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(26) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-25 01:39:14.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(76) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-26 00:02:43.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(37) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-27 00:52:12.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(88) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-28 00:00:15.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(80) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-29 00:00:57.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(73) already exists.
#
# duplicate key value violates unique constraint "time_dim_pkey"
# DETAIL:  Key (start_time)=(2018-11-30 00:22:07.796) already exists.
#
# duplicate key value violates unique constraint "users_dim_pkey"
# DETAIL:  Key (user_id)=(91) already exists.
